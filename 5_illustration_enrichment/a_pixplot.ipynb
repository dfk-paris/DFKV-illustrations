# %% [markdown]
# # Pixplot on DFKV Illustrations
#
# In this notebook, we use the [pixplot](https://github.com/YaleDHLab/pix-plot) process developped by the Yale DH Lab. It uses the HDBSCAN algorithm and UMAP to visualize high dimensional data into a 2D space. That will allow us to have a global idea about the kind of illustrations found, help with the definition of later labels for image classification, and also find duplicates.

# %%
# Installing dependencies
# !pip install https://github.com/yaledhlab/pix-plot/archive/master.zip

# %%
# Specifically hdbscan because dependency problem
# !pip uninstall hdbscan
# !pip install hdbscan

# %%
# Install a version of cudnn that works
# !apt install --allow-change-held-packages libcudnn8=8.1.0.77-1+cuda11.2

# %%
# Mounting Google Drive content
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# Go into the directory where your notebook is
# %cd gdrive/My Drive/newspaper-navigator/newspaper-navigator/notebooks
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/newspaper-navigator/newspaper-navigator/notebooks

# %%
# !pixplot --images "../DFKV_illustrations/DFKV/*.jpg"
# Out:
# 2022-03-30 09:27:44.097024: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-03-30 09:27:58.939843: CUML not available; using umap-learn UMAP
# 2022-03-30 09:27:58.945034: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-30 09:27:58.947691: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-03-30 09:27:59.002418: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %% [markdown]
# To see the results, run `python -m http.server 5000` and go to the url `http://localhost:5000/output`.
